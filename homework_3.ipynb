# %% [markdown]
# Simple CNN:
#
# Learing Rate: 0.001
# Optimizer: ADAM

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Hyperparameters
learning_rate = 0.001
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.Adam(learning_rate)

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# Define the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 8s 10ms/step - loss: 1.5750 - accuracy: 0.4242 - val_loss: 1.2956 - val_accuracy: 0.5330
# Epoch 2/10
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2006 - accuracy: 0.5732 - val_loss: 1.0905 - val_accuracy: 0.6142
# Epoch 3/10
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0423 - accuracy: 0.6342 - val_loss: 0.9834 - val_accuracy: 0.6532
# Epoch 4/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9442 - accuracy: 0.6687 - val_loss: 0.9315 - val_accuracy: 0.6697
# Epoch 5/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.8690 - accuracy: 0.6960 - val_loss: 0.8824 - val_accuracy: 0.6926
# Epoch 6/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8126 - accuracy: 0.7150 - val_loss: 0.8446 - val_accuracy: 0.7031
# Epoch 7/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7592 - accuracy: 0.7365 - val_loss: 0.8528 - val_accuracy: 0.7039
# Epoch 8/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.7175 - accuracy: 0.7507 - val_loss: 0.8782 - val_accuracy: 0.6959
# Epoch 9/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.6789 - accuracy: 0.7627 - val_loss: 0.8429 - val_accuracy: 0.7070
# Epoch 10/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.6404 - accuracy: 0.7758 - val_loss: 0.8433 - val_accuracy: 0.7165
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8433 - accuracy: 0.7165
# Test accuracy: 0.7164999842643738

# %% [markdown]
# Learning Rate = 0.0005
#
# Optimizer = ADAM

# %%
# Hyperparameters
learning_rate = 0.0005
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.Adam(learning_rate)

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.5480 - accuracy: 0.8100 - val_loss: 0.8434 - val_accuracy: 0.7185
# Epoch 2/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.5219 - accuracy: 0.8198 - val_loss: 0.8360 - val_accuracy: 0.7231
# Epoch 3/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.4989 - accuracy: 0.8258 - val_loss: 0.8431 - val_accuracy: 0.7244
# Epoch 4/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.4782 - accuracy: 0.8342 - val_loss: 0.8555 - val_accuracy: 0.7159
# Epoch 5/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.4552 - accuracy: 0.8428 - val_loss: 0.8712 - val_accuracy: 0.7270
# Epoch 6/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.4382 - accuracy: 0.8488 - val_loss: 0.8821 - val_accuracy: 0.7243
# Epoch 7/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.4198 - accuracy: 0.8558 - val_loss: 0.9220 - val_accuracy: 0.7170
# Epoch 8/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.4014 - accuracy: 0.8609 - val_loss: 0.8895 - val_accuracy: 0.7183
# Epoch 9/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.3849 - accuracy: 0.8658 - val_loss: 0.9312 - val_accuracy: 0.7243
# Epoch 10/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.3673 - accuracy: 0.8718 - val_loss: 0.9555 - val_accuracy: 0.7227
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9555 - accuracy: 0.7227
# Test accuracy: 0.7226999998092651

# %% [markdown]
# Learning Rate = 0.001
#
# Optimizer = SGD

# %%
# Hyperparameters
learning_rate = 0.001
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.SGD(learning_rate)

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9135 - accuracy: 0.6920 - val_loss: 1.1185 - val_accuracy: 0.6358
# Epoch 2/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8477 - accuracy: 0.7117 - val_loss: 1.1029 - val_accuracy: 0.6397
# Epoch 3/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8301 - accuracy: 0.7175 - val_loss: 1.0967 - val_accuracy: 0.6414
# Epoch 4/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.8198 - accuracy: 0.7207 - val_loss: 1.0928 - val_accuracy: 0.6444
# Epoch 5/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.8115 - accuracy: 0.7236 - val_loss: 1.0965 - val_accuracy: 0.6423
# Epoch 6/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.8053 - accuracy: 0.7252 - val_loss: 1.0866 - val_accuracy: 0.6469
# Epoch 7/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8000 - accuracy: 0.7268 - val_loss: 1.0859 - val_accuracy: 0.6482
# Epoch 8/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.7953 - accuracy: 0.7280 - val_loss: 1.0828 - val_accuracy: 0.6500
# Epoch 9/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7916 - accuracy: 0.7297 - val_loss: 1.0816 - val_accuracy: 0.6483
# Epoch 10/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7879 - accuracy: 0.7300 - val_loss: 1.0805 - val_accuracy: 0.6501
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0805 - accuracy: 0.6501
# Test accuracy: 0.6500999927520752

# %% [markdown]
# Learning Rate = 0.001
#
# Optimizer = SGD

# %%
# Hyperparameters
learning_rate = 0.01
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.SGD(learning_rate)

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8045 - accuracy: 0.7260 - val_loss: 1.1300 - val_accuracy: 0.6329
# Epoch 2/10
# 782/782 [==============================] - 7s 10ms/step - loss: 0.7885 - accuracy: 0.7295 - val_loss: 1.0846 - val_accuracy: 0.6496
# Epoch 3/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7769 - accuracy: 0.7334 - val_loss: 1.2318 - val_accuracy: 0.6154
# Epoch 4/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7681 - accuracy: 0.7364 - val_loss: 1.1040 - val_accuracy: 0.6479
# Epoch 5/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7624 - accuracy: 0.7380 - val_loss: 1.1899 - val_accuracy: 0.6175
# Epoch 6/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7564 - accuracy: 0.7413 - val_loss: 1.0964 - val_accuracy: 0.6519
# Epoch 7/10
# 782/782 [==============================] - 8s 11ms/step - loss: 0.7517 - accuracy: 0.7402 - val_loss: 1.0811 - val_accuracy: 0.6507
# Epoch 8/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7476 - accuracy: 0.7424 - val_loss: 1.1023 - val_accuracy: 0.6509
# Epoch 9/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7424 - accuracy: 0.7441 - val_loss: 1.0702 - val_accuracy: 0.6567
# Epoch 10/10
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7382 - accuracy: 0.7457 - val_loss: 1.0875 - val_accuracy: 0.6535
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0875 - accuracy: 0.6535
# Test accuracy: 0.6535000205039978

# %% [markdown]
# RES-NET

# %% [markdown]
# Learning rate = 0.001
#
# Optimizer = ADAM

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Hyperparameters
learning_rate = 0.001
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.Adam(learning_rate)

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# Residual Block
def residual_block(x, filters, kernel_size=3, stride=1):
    y = layers.Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    y = layers.BatchNormalization()(y)
    y = layers.Activation('relu')(y)

    y = layers.Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(y)
    y = layers.BatchNormalization()(y)

    if stride != 1 or x.shape[-1] != filters:
        x = layers.Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
        x = layers.BatchNormalization()(x)

    out = layers.add([x, y])
    out = layers.Activation('relu')(out)
    return out

# Define the ResNet model
def resnet_model():
    input_tensor = layers.Input(shape=(32, 32, 3))
    
    x = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(input_tensor)
    
    x = residual_block(x, 64)
    x = residual_block(x, 64)

    x = layers.MaxPooling2D((2, 2))(x)

    x = residual_block(x, 128, stride=1)
    x = residual_block(x, 128)

    x = layers.GlobalAveragePooling2D()(x)
    
    x = layers.Dense(64, activation='relu')(x)
    output_tensor = layers.Dense(10, activation='softmax')(x)

    model = models.Model(inputs=input_tensor, outputs=output_tensor)
    return model

# Create the ResNet model
model = resnet_model()

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   1792        ['input_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_25[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['conv2d_25[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 64)   0           ['add_6[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_11[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 64)   0           ['activation_11[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['add_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_13[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 128)  8320        ['max_pooling2d_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_20[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  activation_15 (Activation)     (None, 16, 16, 128)  0           ['add_8[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 128)  512        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 128)  0           ['activation_15[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 128)  0           ['add_9[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['activation_17[0][0]']
#  alAveragePooling2D)
#
#  dense_6 (Dense)                (None, 64)           8256        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_7 (Dense)                (None, 10)           650         ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 686,922
# Trainable params: 685,130
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 284s 361ms/step - loss: 1.2441 - accuracy: 0.5462 - val_loss: 2.2407 - val_accuracy: 0.4013
# Epoch 2/10
# 782/782 [==============================] - 290s 371ms/step - loss: 0.8317 - accuracy: 0.7055 - val_loss: 1.1368 - val_accuracy: 0.5994
# Epoch 3/10
# 782/782 [==============================] - 307s 392ms/step - loss: 0.6614 - accuracy: 0.7716 - val_loss: 1.1501 - val_accuracy: 0.6507
# Epoch 4/10
# 782/782 [==============================] - 291s 372ms/step - loss: 0.5510 - accuracy: 0.8102 - val_loss: 0.8698 - val_accuracy: 0.7229
# Epoch 5/10
# 782/782 [==============================] - 291s 372ms/step - loss: 0.4786 - accuracy: 0.8345 - val_loss: 0.7664 - val_accuracy: 0.7499
# Epoch 6/10
# 782/782 [==============================] - 293s 375ms/step - loss: 0.4176 - accuracy: 0.8550 - val_loss: 1.4917 - val_accuracy: 0.5966
# Epoch 7/10
# 782/782 [==============================] - 302s 387ms/step - loss: 0.3636 - accuracy: 0.8744 - val_loss: 0.9728 - val_accuracy: 0.7021
# Epoch 8/10
# 782/782 [==============================] - 292s 374ms/step - loss: 0.3198 - accuracy: 0.8902 - val_loss: 1.0296 - val_accuracy: 0.6971
# Epoch 9/10
# 782/782 [==============================] - 294s 376ms/step - loss: 0.2811 - accuracy: 0.9023 - val_loss: 0.7816 - val_accuracy: 0.7499
# Epoch 10/10
# 782/782 [==============================] - 294s 376ms/step - loss: 0.2444 - accuracy: 0.9146 - val_loss: 0.5968 - val_accuracy: 0.8060
# 313/313 [==============================] - 17s 53ms/step - loss: 0.5968 - accuracy: 0.8060
# Test accuracy: 0.8059999942779541

# %% [markdown]
# Stopped calculation of other models since it takes way too long. I expect simmilar results in the following

# %%
learning_rate = 0.01
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.Adam(learning_rate)


# Create the ResNet model
model = resnet_model()

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 64)   1792        ['input_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_35[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_18[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['conv2d_35[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 64)   0           ['add_10[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_20[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['activation_19[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 64)   0           ['add_11[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_21[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 128)  8320        ['max_pooling2d_9[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_22[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 128)  512        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_29[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_23 (Activation)     (None, 16, 16, 128)  0           ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_23[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_24[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  512        ['conv2d_44[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 128)  0           ['activation_23[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 128)  0           ['add_13[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['activation_25[0][0]']
#  obalAveragePooling2D)
#
#  dense_8 (Dense)                (None, 64)           8256        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 10)           650         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 686,922
# Trainable params: 685,130
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# Epoch 1/10
# 106/782 [===>..........................] - ETA: 4:03 - loss: 2.0551 - accuracy: 0.2202
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X22sdW50aXRsZWQ%3D?line=15'>16</a> model.summary()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X22sdW50aXRsZWQ%3D?line=17'>18</a> # Train the model
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X22sdW50aXRsZWQ%3D?line=18'>19</a> history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X22sdW50aXRsZWQ%3D?line=20'>21</a> # Visualize training history
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X22sdW50aXRsZWQ%3D?line=21'>22</a> acc = history.history['accuracy']
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\Maurice\anaconda3\envs\ANNTF\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
learning_rate = 0.001
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.SCD(learning_rate)


# Create the ResNet model
model = resnet_model()

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')

# %%
learning_rate = 0.01
batch_size = 64
epochs = 10
optimizer = tf.keras.optimizers.SCD(learning_rate)


# Create the ResNet model
model = resnet_model()

# Compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(test_images, test_labels))

# Visualize training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
